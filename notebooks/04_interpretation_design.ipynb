# %%
"""
AI 결과를 사람이 이해할 수 있게 변환
1. anomaly score vs residual 비교
2. 시간 추세 분석
3. 알람 조건 설계
4. false alarm 제거 기준 정리

질문 : "AI 가 이상하다는데 그래서 뭐가 문제죠?"
      "언제 정비하죠?
답을 할 수 있어야 한다.

산출물
- 후처리 로직 정의서
- spring boot 조건 설계 초안

"""
